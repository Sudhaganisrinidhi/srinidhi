# %% [markdown]
# <a href="https://colab.research.google.com/github/Sudhaganisrinidhi/srinidhi/blob/main/PNS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
def load_data(cricket_dataset_csv):
    df=pd.read_csv(cricket_dataset_csv)
    return df

# %%
def plot_histogram(df,column,bins=10):
  plt.figure(figsize=(8,6))
  sns.histplot(df[column],bins=bins,kde=true,color='blue')
  plt.title(f'histogram of{column}')
  plt.xlabel(column)
  plt.ylable('frequency')
  plt.show()

# %%
def plot_scatter(df,x_column,y_column):
  plt.figure(figsize=(8,6))
  sns.scatterplot(x=df[x_column],y=df[y_column],color='red')
  plt.title(f'scatter plot of {x_column} vs {y_column}')
  plt.xlable(x_column)
  plt.ylable(y_column)
  plt.show()

# %%
def plot_bar_chart(df,x_column,y_column):
  plt.figure(figsize=(10,6))
  sns.barplot(x=df[x_column],y=df[y_column],palette='viridis')
  plt.title(f'bar chart of {y_column} by {x_column}')
  plt.xlabel(x_column)
  plt.ylabel(y_column)
  plt.xticks(rotation=45)
  plt.show()

# %%
file_path='cricket_dataset.csv'

# %%
plot_histogram(data,'Runs')
plot_histogram(data,'Wickets')

# %%
plot_scatter(data, 'Matches', 'Runs')
plot_scatter(data, 'Economy Rate', 'Wickets')

# %%
plot_bar_chart(data, 'Player', '50s')
plot_bar_chart(data, 'Player', '100s')
# Out:
# <ipython-input-14-634ac5e7e2a6>:27: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df[x_column], y=df[y_column], palette='viridis')
# <ipython-input-14-634ac5e7e2a6>:27: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df[x_column], y=df[y_column], palette='viridis')
